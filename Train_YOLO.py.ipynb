# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 871.8/871.8 kB 24.0 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from ultralytics import YOLO


def train_model():
    model = YOLO('yolov8m.pt')  # Load pretrained model

    # Train the model
    results = model.train(task='detect',
                          model='yolov8m.pt',
                          mode='train',
                          data='/content/drive/MyDrive/Train_YOLO/my_dataset_7/data.yaml',
                          epochs=200,
                          imgsz=768,
                          batch = 20,
                          device=0,
                          project='/content/drive/MyDrive/Train_YOLO/runs_7',
                          name = 'runs_000',
                          hsv_h = 0.2, # (float) image HSV-Hue augmentation (fraction)
                          hsv_s = 0.4, # (float) image HSV-Saturation augmentation (fraction)
                          hsv_v = 0.4, # (float) image HSV-Value augmentation (fraction)
                          degrees = 7.0, # (float) image rotation (+/- deg)
                          translate = 0.5, # (float) image translation (+/- fraction)
                          scale = 0.7, # (float) image scale (+/- gain)
                          shear = 10.0, # (float) image shear (+/- deg)
                          perspective = 0.0, # (float) image perspective (+/- fraction), range 0-0.001
                          flipud = 0.0, # (float) image flip up-down (probability)
                          fliplr = 0.5, # (float) image flip left-right (probability)
                          bgr = 0.0, # (float) image channel BGR (probability)
                          mosaic = 0.25, # (float) image mosaic (probability)
                          mixup = 0, # (float) image mixup (probability)
                          copy_paste = 0.0, # (float) segment copy-paste (probability)
                          auto_augment = 'randaugment', # (str) auto augmentation policy for classification (randaugment, autoaugment, augmix)
                          erasing = 0.15, # (float) probability of random erasing during classification training (0-0.9), 0 means no erasing, must be less than 1.0.
                          crop_fraction = 1, # (float) image crop fraction for classification (0.1-1), 1.0 means no crop, must be greater than 0,
                          close_mosaic = 15)
    return results


if __name__ == '__main__':
    train_model()
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 371MB/s]
# Ultralytics YOLOv8.2.90 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
